# %%
import lightkurve as lk
import matplotlib.pyplot as plt
import numpy as np

search = lk.search_lightcurve("Beta Dor", mission="TESS")
search
# Out:
# /home/adamarthurryan/micromamba/envs/jupyter/lib/python3.13/site-packages/lightkurve/prf/__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(
# SearchResult containing 139 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 03 2018              SPOC     120   149346418      0.0
#   1 TESS Sector 02 2018              SPOC     120   149346418      0.0
#   2 TESS Sector 01 2018              SPOC     120   149346418      0.0
#   3 TESS Sector 04 2018              SPOC     120   149346418      0.0
#   4 TESS Sector 05 2018              SPOC     120   149346418      0.0
#   5 TESS Sector 06 2018              SPOC     120   149346418      0.0
# ...

# %%
sector_num = 90
sectors = np.where(search.table['mission'] == f'TESS Sector {sector_num}' and search.table['author'=="TESS"])
sectors
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 sector_num = 90
# ----> 2 sectors = np.where(search.table['mission'] == f'TESS Sector {sector_num}' and search.table['author'=="TESS"]).all()
#       3 sectors
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
print(search[sectors[0]])
lc = search[sectors[0]].download_all()
lc.plot()
# Out:
# SearchResult containing 3 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 90 2025   SPOC      20   149346418      0.0
#   1 TESS Sector 90 2025   SPOC     120   149346418      0.0
#   2 TESS Sector 90 2025    QLP     200   149346418      0.0
# /home/adamarthurryan/micromamba/envs/jupyter/lib/python3.13/site-packages/lightkurve/collections.py:263: LightkurveWarning: Some but not all of the light curves in the collection appear to be normalized. You may wish to use `normalize=True` to ensure all are normalized.
#   warnings.warn(
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux'>
