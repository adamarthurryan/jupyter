# %%
# tools for calculating number density of a star field
##########

from astropy.table import Table
from astropy.coordinates import SkyCoord

previous_filename = "m13_01.hdf5"
m13_stars = Table.read(previous_filename, path="gaia")
#m13_simbad = Table.read(previous_filename, path="simbad/initial")

# %%
from common import plot_number_density

plot_number_density(m13_stars)

# %%
# idea:
#    slice stars according to various isochrones
#    then examine the number density distribution of the various populations
#    look for distributions that show large concentrations in the m13 region
