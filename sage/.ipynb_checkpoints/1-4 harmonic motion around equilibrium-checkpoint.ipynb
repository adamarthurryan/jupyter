# %%
a=var('a')
E=var('E')
v(x)=E/a^4*x^4 + 4*a*x^3 - 8*a^2*x^2
Dv=diff(v,x,1)
D2v=diff(v,x,2)
plot(v(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/micromamba/envs/sage/lib/python3.12/site-packages/sage/ext/fast_callable.pyx:765, in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:10642)()
#     764 try:
# --> 765     ind = self._vars.index(var_name)
#     766 except ValueError:
#
# ValueError: 'a' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 7
#       5 dv=diff(v,x,Integer(1))
#       6 d2v=diff(v,x,Integer(2))
# ----> 7 plot(v(x))
#
# File ~/micromamba/envs/sage/lib/python3.12/site-packages/sage/misc/decorators.py:507, in options.__call__.<locals>.wrapper(*args, **kwds)
#     505     options['__original_opts'] = kwds
#     506 options.update(kwds)
# ...
