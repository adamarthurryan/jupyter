# %%
# %display latex

f(x)=x*tan(x)
display(f)

p1=plot(f)
p2=plot(1)
show(p1+p2)
# Out:
# x |--> x*tan(x)
# Graphics object consisting of 2 graphics primitives

# %%
find_root(f(x)==1, 0.5, 1)
# Out:
# 0.8603335890193797
