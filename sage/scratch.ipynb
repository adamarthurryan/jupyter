# %%
# %display latex
b=var('b')
n=var('n')
a=var('a')
assume(a>0)
assume(n>0)
assume(n, 'integer')

f(x) = (sin((n*pi/a)*x))^2
integrate (f, x, 0, a)
# Out:
# 1/2*a

# %%
x1=(2/a)*integrate(x*f,x, 0, a).full_simplify()
x1
# Out:
# 1/2*a

# %%
x2=(2/a*integrate(x*x*f, x, 0, a)).full_simplify()
x2
# Out:
# 1/6*(2*pi^2*a^2*n^2 - 3*a^2)/(pi^2*n^2)

# %%
x2-x1^2
# Out:
# -1/4*a^2 + 1/6*(2*pi^2*a^2*n^2 - 3*a^2)/(pi^2*n^2)
