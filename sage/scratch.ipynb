# %%
# %display latex
f=sqrt(1-1/x)
f
# Out:
# sqrt(-1/x + 1)

# %%
derivative(f,x)
# Out:
# 1/2/(x^2*sqrt(-1/x + 1))

# %%
derivative(f,x,2)
# Out:
# -1/(x^3*sqrt(-1/x + 1)) - 1/4/(x^4*(-1/x + 1)^(3/2))
