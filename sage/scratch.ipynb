# %%
# %display latex
a=var('a')
assume(a>0)
f(u) = (a/(4*u*(a-u)))^(1/2)
integrate(f, u, 0, a)
# Out:
# 1/2*integrate(sqrt(a/(a*u - u^2)), u, 0, a)

# %%
g(u)=1/(a-u)^(1/2)
integrate(g,u)
# Out:
# u |--> -2*sqrt(a - u)

# %%
h(u)=a/(4*u*(a-u))
derivative(h,u)
# Out:
# u |--> -1/4*a/((a - u)*u^2) + 1/4*a/((a - u)^2*u)
