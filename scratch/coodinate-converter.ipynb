# %%
from astropy.coordinates import SkyCoord
import astropy.units as u

simbad_str = "14 12 37.5331103311 +04 03 36.116569918"
coord = SkyCoord(simbad_str, unit=(u.hourangle, u.deg), frame='icrs')
print(coord)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (213.15638796, 4.06003238)>
