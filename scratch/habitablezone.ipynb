# %%
import astropy.units as u
import astropy.constants as c
import numpy as np

solar_constant = 1361 * u.W/u.m**2
solar_solid_angle = ((c.R_sun / u.AU)**2 * np.pi).to(u.sr, equivalencies=u.dimensionless_angles())
solar_intensity = solar_constant *4*np.pi/ solar_solid_angle

#temperature = solar_intensity.to(u.K, equivalencies=u.brightness_temperature(1*u.MHz))

print(solar_intensity)

average_energy=solar_constant*(c.R_earth*2*np.pi)/(c.R_earth**2*np.pi*4)
print(average_energy)
temp = (1/c.sigma_sb*average_energy)**(1/4)
print(temp)
# Out:
# 251724179.4813244 W / (sr m2)
# 0.00010669321584797982 W / m3
# 6.586144686480639 K / m(1/4)
